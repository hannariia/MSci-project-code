# %%
import numpy as np
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Model 1

model_1 = pd.DataFrame(data=None, columns = ["P_RMS", "P_variance", "S_RMS", "S_variance"])
model_1["P_RMS"] = [135.33, 39.79, 35.31, 33.88, 32.52, 32.13, 31.58, 31.41, 31.09]
model_1["P_variance"] = [0.01832, 0.00158, 0.00125, 0.00115, 0.00106, 0.00103, 0.00100, 0.00099, 0.00097]
model_1["S_RMS"] = [267.84, 87.78, 75.22, 68.83, 64.33, 61.83, 60.14, 58.78, 57.99]
model_1["S_variance"] = [0.07174, 0.00771, 0.00566, 0.00474, 0.00414, 0.00382, 0.00362, 0.00345, 0.00336]

# %%
# Model 2

model_2 = pd.DataFrame(data=None, columns = ["P_RMS", "P_variance", "S_RMS", "S_variance"])
model_2["P_RMS"] = [135.49, 73.45, 57.35, 51.22, 49.43, 49.38, 48.33, 49.2, 48.53]
model_2["P_variance"] = [0.01836,0.0054,0.00329,0.00262,0.00244,0.00244,0.00234,0.00242,0.00235]
model_2["S_RMS"] = [268.38,102.11,88.17,78.81,77.58,77.14,76.19,77.1,76.55]
model_2["S_variance"] = [0.07204,0.01043,0.00777,0.00621,0.00602,0.00595,0.00581,0.00594,0.00586]

# %%
# Model 3

model_3 = pd.DataFrame(data=None, columns = ["P_RMS", "P_variance", "S_RMS", "S_variance"])
model_3["P_RMS"] = [128.41, 35.59, 33.02, 32.49, 32.07, 31.93, 31.69, 31.69, 31.56]
model_3["P_variance"] = [0.01649, 0.00127, 0.00109, 0.00106, 0.00103, 0.00102, 0.00100, 0.00100, 0.00100]
model_3["S_RMS"] = [215.08, 65.70, 60.33, 57.85, 56.07, 55.11, 54.59, 54.26, 53.99]
model_3["S_variance"] = [0.04626, 0.00432, 0.00364, 0.00335, 0.00314, 0.00304, 0.00298, 0.00294, 0.00292]

# %%
plt.show()

# Plot model convergence

x_axis = np.arange(0,9,1)

plt.plot(x_axis, model_1["P_variance"], marker='o', markersize=0.1, linestyle='-', label="Model 1, P variance", color='red')
plt.plot(x_axis, model_1["S_variance"], marker='o',markersize=0.1, linestyle='--', label="Model 1, S variance", color='red')

plt.plot(x_axis, model_2["P_variance"], marker='o', markersize=0.1, linestyle='-', label="Model 2, P variance", color='blue')
plt.plot(x_axis, model_2["S_variance"], marker='o',markersize=0.1, linestyle='--', label="Model 2, S variance", color='blue')



plt.ylim(0,0.08)
plt.xlim(0,8)
plt.xlabel('Inversion/relocation step')
plt.ylabel('Data variance')
plt.title("Variance reduction for different models over 5 iterations")
plt.grid()
plt.legend()

plt.show()
